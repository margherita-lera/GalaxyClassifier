# %%
import matplotlib.pyplot as plt
import pickle
import sys
import os

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax.grid(alpha=0.3)

path = './non_mapped'
for file in os.scandir(path):
    if file.is_file() and file.name.endswith('.pickle'):
        with open(file.path, 'rb') as f:
            losses = pickle.load(f)
            train_score = losses['epoch']
            val_score = losses['vepoch']

            ax.plot(train_score, lw=1, label=f'{file.name} train loss', ls='--')
            ax.plot(val_score, lw=1, label=f'{file.name} val loss', ls='-')
ax.set_xlim(0, 500)
ax.set_ylim(0.05, 0.175)
ax.set_title('Training vs Validation loss for each architecture')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.legend(fontsize=8, loc='upper right')
plt.show()
